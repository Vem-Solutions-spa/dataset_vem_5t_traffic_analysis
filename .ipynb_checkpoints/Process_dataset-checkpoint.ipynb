# %%
import pandas as pd

# %%
SIZE = 500000
NAMES = ['device_id', 'recording_date', 'lat', 'lon', 'speed', 'heading', 'gps_quality', 'engine_status',
        'acceleration', 'meters']

i = 0
for chunck in pd.read_csv('top_2017_06_01.csv', names=NAMES, chunksize=SIZE, iterator=True, 
                          parse_dates=['recording_date']):
    piece = chunck[chunck.lat.between(45.00678, 45.14021) & chunck.lon.between(7.57785, 7.77337)]
    # piece['loc'] = piece.loc[:, ['lon', 'lat']].apply(lambda c: list(c[0], c[1]), axis=1)
    if i == 0:
        piece.to_csv('turin_2017_06_01.csv', index=False)
        #piece.to_json('turin_2017_06_01.json', orient='records', date_unit='s')
    else:
        piece.to_csv('turin_2017_06_01.csv', index=False, mode='a', header=False)    i += 1
    if i%5 == 0:
        print('Did %d chuncks' %i)
# Out:
# Did 5 chuncks
# Did 10 chuncks
# Did 15 chuncks
# Did 20 chuncks
# Did 25 chuncks
# Did 30 chuncks
# Did 35 chuncks
# Did 40 chuncks
# Did 45 chuncks
# Did 50 chuncks
# Did 55 chuncks
# Did 60 chuncks
# Did 65 chuncks
# Did 70 chuncks
# Did 75 chuncks
# Did 80 chuncks
# Did 85 chuncks
# Did 90 chuncks
# Did 95 chuncks
# Did 100 chuncks
# Did 105 chuncks
# Did 110 chuncks
# Did 115 chuncks
# Did 120 chuncks
# Did 125 chuncks
# Did 130 chuncks
# Did 135 chuncks
# Did 140 chuncks
# Did 145 chuncks
# Did 150 chuncks
# Did 155 chuncks
# Did 160 chuncks
# Did 165 chuncks
# Did 170 chuncks
# Did 175 chuncks
# Did 180 chuncks
# Did 185 chuncks
# Did 190 chuncks
# Did 195 chuncks
# Did 200 chuncks
# Did 205 chuncks
# Did 210 chuncks
# Did 215 chuncks
# Did 220 chuncks
# Did 225 chuncks
# Did 230 chuncks

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client.vem

# %%
col = db.june2017

# %%
# !mongoimport -d vem -c june2017 --type csv --file turin_2017_06_01.csv --headerline
# Out:
# 2018-07-09T11:06:25.731+0200	connected to: localhost
# 2018-07-09T11:06:28.714+0200	[........................] vem.june2017	14.3MB/1.07GB (1.3%)
# 2018-07-09T11:06:31.715+0200	[........................] vem.june2017	29.6MB/1.07GB (2.7%)
# 2018-07-09T11:06:34.715+0200	[........................] vem.june2017	44.8MB/1.07GB (4.1%)
# 2018-07-09T11:06:37.714+0200	[#.......................] vem.june2017	59.3MB/1.07GB (5.4%)
# 2018-07-09T11:06:40.716+0200	[#.......................] vem.june2017	70.9MB/1.07GB (6.5%)
# 2018-07-09T11:06:43.714+0200	[#.......................] vem.june2017	85.7MB/1.07GB (7.8%)
# 2018-07-09T11:06:46.714+0200	[##......................] vem.june2017	100MB/1.07GB (9.2%)
# 2018-07-09T11:06:49.714+0200	[##......................] vem.june2017	115MB/1.07GB (10.5%)
# 2018-07-09T11:06:52.715+0200	[##......................] vem.june2017	129MB/1.07GB (11.8%)
# 2018-07-09T11:06:55.714+0200	[###.....................] vem.june2017	145MB/1.07GB (13.2%)
# 2018-07-09T11:06:58.717+0200	[###.....................] vem.june2017	159MB/1.07GB (14.5%)
# 2018-07-09T11:07:01.717+0200	[###.....................] vem.june2017	170MB/1.07GB (15.5%)
    col.update_one({'_id': doc['_id']}, {'$push': {'loc': [doc['lon'], doc['lat']]}})
    if j%100000 == 0:
        print('We updated %d docs' %j)
    j += 1
# Out:
# We updated 0 docs
# We updated 100000 docs
# We updated 200000 docs
# We updated 300000 docs
# We updated 400000 docs
# We updated 500000 docs
# We updated 600000 docs
# We updated 700000 docs
# We updated 800000 docs
# We updated 900000 docs
# We updated 1000000 docs
# We updated 1100000 docs
# We updated 1200000 docs
# We updated 1300000 docs
# We updated 1400000 docs
# We updated 1500000 docs
# We updated 1600000 docs
# We updated 1700000 docs
# We updated 1800000 docs
# We updated 1900000 docs
# We updated 2000000 docs
# We updated 2100000 docs
# We updated 2200000 docs
# We updated 2300000 docs
# We updated 2400000 docs
# We updated 2500000 docs
# We updated 2600000 docs
# We updated 2700000 docs
# We updated 2800000 docs
# We updated 2900000 docs
# We updated 3000000 docs
# We updated 3100000 docs
# We updated 3200000 docs
# We updated 3300000 docs
# We updated 3400000 docs
# We updated 3500000 docs
# We updated 3600000 docs
# We updated 3700000 docs
# We updated 3800000 docs
# We updated 3900000 docs
# We updated 4000000 docs
# We updated 4100000 docs
# We updated 4200000 docs
# We updated 4300000 docs
# We updated 4400000 docs
# We updated 4500000 docs
# We updated 4600000 docs
# We updated 4700000 docs
# We updated 4800000 docs
# We updated 4900000 docs
# We updated 5000000 docs
# We updated 5100000 docs
# We updated 5200000 docs
# We updated 5300000 docs
# We updated 5400000 docs
# We updated 5500000 docs
# We updated 5600000 docs
# We updated 5700000 docs
# We updated 5800000 docs
# We updated 5900000 docs
# We updated 6000000 docs
# We updated 6100000 docs
# We updated 6200000 docs
# We updated 6300000 docs
# We updated 6400000 docs
# We updated 6500000 docs
# We updated 6600000 docs
# We updated 6700000 docs
# We updated 6800000 docs
# We updated 6900000 docs
# We updated 7000000 docs
# We updated 7100000 docs
# We updated 7200000 docs
# We updated 7300000 docs
# We updated 7400000 docs
# We updated 7500000 docs
# We updated 7600000 docs
# We updated 7700000 docs
# We updated 7800000 docs
# We updated 7900000 docs
# We updated 8000000 docs
# We updated 8100000 docs
# We updated 8200000 docs
# We updated 8300000 docs
# We updated 8400000 docs
# We updated 8500000 docs
# We updated 8600000 docs
# We updated 8700000 docs
# We updated 8800000 docs
# We updated 8900000 docs
# We updated 9000000 docs
# We updated 9100000 docs
# We updated 9200000 docs
# We updated 9300000 docs
# We updated 9400000 docs
# We updated 9500000 docs
# We updated 9600000 docs
# We updated 9700000 docs
# We updated 9800000 docs
# We updated 9900000 docs
# We updated 10000000 docs
# We updated 10100000 docs
# We updated 10200000 docs
# We updated 10300000 docs
# We updated 10400000 docs
# We updated 10500000 docs
# We updated 10600000 docs
# We updated 10700000 docs
# We updated 10800000 docs
# We updated 10900000 docs
# We updated 11000000 docs
# We updated 11100000 docs
# We updated 11200000 docs
# We updated 11300000 docs
# We updated 11400000 docs
# We updated 11500000 docs
# We updated 11600000 docs
# We updated 11700000 docs
# We updated 11800000 docs
# We updated 11900000 docs
# We updated 12000000 docs
# We updated 12100000 docs
# We updated 12200000 docs
# We updated 12300000 docs
# We updated 12400000 docs
# We updated 12500000 docs
# We updated 12600000 docs
# We updated 12700000 docs
# We updated 12800000 docs
# We updated 12900000 docs
# We updated 13000000 docs
# We updated 13100000 docs
# We updated 13200000 docs
# We updated 13300000 docs
# We updated 13400000 docs
# We updated 13500000 docs
# We updated 13600000 docs
# We updated 13700000 docs
# We updated 13800000 docs
# We updated 13900000 docs
# We updated 14000000 docs
# We updated 14100000 docs
# We updated 14200000 docs
# We updated 14300000 docs
# We updated 14400000 docs
# We updated 14500000 docs
# We updated 14600000 docs
# We updated 14700000 docs
# We updated 14800000 docs
# We updated 14900000 docs
# We updated 15000000 docs
# We updated 15100000 docs
# We updated 15200000 docs
# We updated 15300000 docs
# We updated 15400000 docs
# We updated 15500000 docs
# We updated 15600000 docs
# We updated 15700000 docs
# We updated 15800000 docs
# We updated 15900000 docs
# We updated 16000000 docs
# We updated 16100000 docs
# We updated 16200000 docs

# %%
db.collection_names()
# Out:
# ['june2017']

# %%
col.drop()

# %%
col.count({'loc': {'$exists': False}})
# Out:
# 111668553

# %%
# !mongoimport --help

# %%
i = 0

for doc in col.find({'loc': {'$exists': False}}):
    col.update_one({'_id': doc['_id']}, {'$push': {'loc': {'LON': doc['lon'], 'LAT': doc['lat']}}})
    i += 1
    if i%10000 == 0:
        print("We did %d documents" %i)
# Out:
# We did 10000 documents
# We did 20000 documents
# We did 30000 documents
# We did 40000 documents
# We did 50000 documents
# We did 60000 documents
# We did 70000 documents
# We did 80000 documents
# We did 90000 documents
# We did 100000 documents
# We did 110000 documents
# We did 120000 documents
# We did 130000 documents
# We did 140000 documents
# We did 150000 documents
# We did 160000 documents
# We did 170000 documents
# We did 180000 documents
# We did 190000 documents
# We did 200000 documents
# We did 210000 documents
# We did 220000 documents
# We did 230000 documents
# We did 240000 documents
# We did 250000 documents
# We did 260000 documents
# We did 270000 documents
# We did 280000 documents
# We did 290000 documents
# We did 300000 documents
# We did 310000 documents
# We did 320000 documents
# We did 330000 documents
# We did 340000 documents
# We did 350000 documents
# We did 360000 documents
# We did 370000 documents
# We did 380000 documents
# We did 390000 documents
# We did 400000 documents
# We did 410000 documents
# We did 420000 documents
# We did 430000 documents
# We did 440000 documents
# We did 450000 documents
# We did 460000 documents
# We did 470000 documents
# We did 480000 documents
# We did 490000 documents
# We did 500000 documents
# We did 510000 documents
# We did 520000 documents
# We did 530000 documents
# We did 540000 documents
# We did 550000 documents
# We did 560000 documents
# We did 570000 documents
# We did 580000 documents
# We did 590000 documents
# We did 600000 documents
# We did 610000 documents
# We did 620000 documents
# We did 630000 documents
# We did 640000 documents
# We did 650000 documents
# We did 660000 documents
# We did 670000 documents
# We did 680000 documents
# We did 690000 documents
# We did 700000 documents
# We did 710000 documents
# We did 720000 documents
# We did 730000 documents
# We did 740000 documents
# We did 750000 documents
# We did 760000 documents
# We did 770000 documents
# We did 780000 documents
# We did 790000 documents
# We did 800000 documents
# We did 810000 documents
# We did 820000 documents
# We did 830000 documents
# We did 840000 documents
# We did 850000 documents
# We did 860000 documents
# We did 870000 documents
# We did 880000 documents
# We did 890000 documents
# We did 900000 documents
# We did 910000 documents
# We did 920000 documents
# We did 930000 documents
# We did 940000 documents
# We did 950000 documents
# We did 960000 documents
# We did 970000 documents
# We did 980000 documents
# We did 990000 documents
# We did 1000000 documents
# We did 1010000 documents
# We did 1020000 documents
# We did 1030000 documents
# We did 1040000 documents
# We did 1050000 documents
# We did 1060000 documents
# We did 1070000 documents
# We did 1080000 documents
# We did 1090000 documents
# We did 1100000 documents
# We did 1110000 documents
# We did 1120000 documents
# We did 1130000 documents
# We did 1140000 documents
# We did 1150000 documents
# We did 1160000 documents
# We did 1170000 documents
# We did 1180000 documents
# We did 1190000 documents
# We did 1200000 documents
# We did 1210000 documents
# We did 1220000 documents
# We did 1230000 documents
# We did 1240000 documents
# We did 1250000 documents
# We did 1260000 documents
# We did 1270000 documents
# We did 1280000 documents
# We did 1290000 documents
# We did 1300000 documents
# We did 1310000 documents
# We did 1320000 documents
# We did 1330000 documents
# We did 1340000 documents
# We did 1350000 documents
# We did 1360000 documents
# We did 1370000 documents
# We did 1380000 documents
# We did 1390000 documents
# We did 1400000 documents
# We did 1410000 documents
# We did 1420000 documents
# We did 1430000 documents
# We did 1440000 documents
# We did 1450000 documents
# We did 1460000 documents
# We did 1470000 documents
# We did 1480000 documents
# We did 1490000 documents
# We did 1500000 documents
# We did 1510000 documents
# We did 1520000 documents
# We did 1530000 documents
# We did 1540000 documents
# We did 1550000 documents
# We did 1560000 documents
# We did 1570000 documents
# We did 1580000 documents
# We did 1590000 documents
# We did 1600000 documents
# We did 1610000 documents
# We did 1620000 documents
# We did 1630000 documents
# We did 1640000 documents
# We did 1650000 documents
# We did 1660000 documents
# We did 1670000 documents
# We did 1680000 documents
# We did 1690000 documents
# We did 1700000 documents
# We did 1710000 documents
# We did 1720000 documents
# We did 1730000 documents
# We did 1740000 documents
# We did 1750000 documents
# We did 1760000 documents
# We did 1770000 documents
# We did 1780000 documents
# We did 1790000 documents
# We did 1800000 documents
# We did 1810000 documents
# We did 1820000 documents
# We did 1830000 documents
# We did 1840000 documents
# We did 1850000 documents
# We did 1860000 documents
# We did 1870000 documents
# We did 1880000 documents
# We did 1890000 documents
# We did 1900000 documents
# We did 1910000 documents
# We did 1920000 documents
# We did 1930000 documents
# We did 1940000 documents
# We did 1950000 documents
# We did 1960000 documents
# We did 1970000 documents
# We did 1980000 documents
# We did 1990000 documents
# We did 2000000 documents
# We did 2010000 documents
# We did 2020000 documents
# We did 2030000 documents
# We did 2040000 documents
# We did 2050000 documents
# We did 2060000 documents
# We did 2070000 documents
# We did 2080000 documents
# We did 2090000 documents
# We did 2100000 documents
# We did 2110000 documents
# We did 2120000 documents
# We did 2130000 documents
# We did 2140000 documents
# We did 2150000 documents
# We did 2160000 documents
# We did 2170000 documents
# We did 2180000 documents
# We did 2190000 documents
# We did 2200000 documents
# We did 2210000 documents
# We did 2220000 documents
# We did 2230000 documents
# We did 2240000 documents
# We did 2250000 documents
# We did 2260000 documents
# We did 2270000 documents
# We did 2280000 documents
# We did 2290000 documents
# We did 2300000 documents
# We did 2310000 documents
# We did 2320000 documents
# We did 2330000 documents
# We did 2340000 documents
# We did 2350000 documents
# We did 2360000 documents
# We did 2370000 documents
# We did 2380000 documents
# We did 2390000 documents
# We did 2400000 documents
# We did 2410000 documents
# We did 2420000 documents
# We did 2430000 documents
# We did 2440000 documents
# We did 2450000 documents
# We did 2460000 documents
# We did 2470000 documents
# We did 2480000 documents
# We did 2490000 documents
# We did 2500000 documents
# We did 2510000 documents
# We did 2520000 documents
# We did 2530000 documents
# We did 2540000 documents
# We did 2550000 documents
# We did 2560000 documents
# We did 2570000 documents
# We did 2580000 documents
# We did 2590000 documents
# We did 2600000 documents
# We did 2610000 documents
# We did 2620000 documents
# We did 2630000 documents
# We did 2640000 documents
# We did 2650000 documents
# We did 2660000 documents
# We did 2670000 documents
# We did 2680000 documents
# We did 2690000 documents
# We did 2700000 documents
# We did 2710000 documents
# We did 2720000 documents
# We did 2730000 documents
# We did 2740000 documents
# We did 2750000 documents
# We did 2760000 documents
# We did 2770000 documents
# We did 2780000 documents
# We did 2790000 documents
# We did 2800000 documents
# We did 2810000 documents
# We did 2820000 documents
# We did 2830000 documents
# We did 2840000 documents
# We did 2850000 documents
# We did 2860000 documents
# We did 2870000 documents
# We did 2880000 documents
# We did 2890000 documents
# We did 2900000 documents
# We did 2910000 documents
# We did 2920000 documents
# We did 2930000 documents
# We did 2940000 documents
# We did 2950000 documents
# We did 2960000 documents
# We did 2970000 documents
# We did 2980000 documents
# We did 2990000 documents
# We did 3000000 documents
# We did 3010000 documents
# We did 3020000 documents
# We did 3030000 documents
# We did 3040000 documents
# We did 3050000 documents
# We did 3060000 documents
# We did 3070000 documents
# We did 3080000 documents
# We did 3090000 documents
# We did 3100000 documents
# We did 3110000 documents
# We did 3120000 documents
# We did 3130000 documents
# We did 3140000 documents
# We did 3150000 documents
# We did 3160000 documents
# We did 3170000 documents
# We did 3180000 documents
# We did 3190000 documents
# We did 3200000 documents
# We did 3210000 documents
# We did 3220000 documents
# We did 3230000 documents
# We did 3240000 documents
# We did 3250000 documents
# We did 3260000 documents
# We did 3270000 documents
# We did 3280000 documents
# We did 3290000 documents
# We did 3300000 documents
# We did 3310000 documents
# We did 3320000 documents
# We did 3330000 documents
# We did 3340000 documents
# We did 3350000 documents
# We did 3360000 documents
# We did 3370000 documents
# We did 3380000 documents
# We did 3390000 documents
# We did 3400000 documents
# We did 3410000 documents
# We did 3420000 documents
# We did 3430000 documents
# We did 3440000 documents
# We did 3450000 documents
# We did 3460000 documents
# We did 3470000 documents
# We did 3480000 documents
# We did 3490000 documents
# We did 3500000 documents
# We did 3510000 documents
# We did 3520000 documents
# We did 3530000 documents
# We did 3540000 documents
# We did 3550000 documents
# We did 3560000 documents
# We did 3570000 documents
# We did 3580000 documents
# We did 3590000 documents
# We did 3600000 documents
# We did 3610000 documents
# We did 3620000 documents
# We did 3630000 documents
# We did 3640000 documents
# We did 3650000 documents
# We did 3660000 documents
# We did 3670000 documents
# We did 3680000 documents
# We did 3690000 documents
# We did 3700000 documents
# We did 3710000 documents
# We did 3720000 documents
# We did 3730000 documents
# We did 3740000 documents
# We did 3750000 documents
# We did 3760000 documents
# We did 3770000 documents
# We did 3780000 documents
# We did 3790000 documents
# We did 3800000 documents
# We did 3810000 documents
# We did 3820000 documents
# We did 3830000 documents
# We did 3840000 documents
# We did 3850000 documents
# We did 3860000 documents
# We did 3870000 documents
# We did 3880000 documents
# We did 3890000 documents
# We did 3900000 documents
# We did 3910000 documents
# We did 3920000 documents
# We did 3930000 documents
# We did 3940000 documents
# We did 3950000 documents
# We did 3960000 documents
# We did 3970000 documents
# We did 3980000 documents
# We did 3990000 documents
# We did 4000000 documents
# We did 4010000 documents
# We did 4020000 documents
# We did 4030000 documents
# We did 4040000 documents
# We did 4050000 documents
# We did 4060000 documents
# We did 4070000 documents
# We did 4080000 documents
# We did 4090000 documents
# We did 4100000 documents
# We did 4110000 documents
# We did 4120000 documents
# We did 4130000 documents
# We did 4140000 documents
# We did 4150000 documents
# We did 4160000 documents
# We did 4170000 documents
# We did 4180000 documents
# We did 4190000 documents
# We did 4200000 documents
# We did 4210000 documents
# We did 4220000 documents
# We did 4230000 documents
# We did 4240000 documents
# We did 4250000 documents
# We did 4260000 documents
# We did 4270000 documents
# We did 4280000 documents
# We did 4290000 documents
# We did 4300000 documents
# We did 4310000 documents
# We did 4320000 documents
# We did 4330000 documents
# We did 4340000 documents
# We did 4350000 documents
# We did 4360000 documents
# We did 4370000 documents
# We did 4380000 documents
# We did 4390000 documents
# We did 4400000 documents
# We did 4410000 documents
# We did 4420000 documents
# We did 4430000 documents
# We did 4440000 documents
# We did 4450000 documents
# We did 4460000 documents
# We did 4470000 documents
# We did 4480000 documents
# We did 4490000 documents
# We did 4500000 documents
# We did 4510000 documents
# We did 4520000 documents
# We did 4530000 documents
# We did 4540000 documents
# We did 4550000 documents
# We did 4560000 documents
# We did 4570000 documents
# We did 4580000 documents
# We did 4590000 documents
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-c758c47fc82d> in <module>()
#       2
#       3 for doc in col.find({'loc': {'$exists': False}}):
# ----> 4     col.update_one({'_id': doc['_id']}, {'$push': {'loc': {'LON': doc['lon'], 'LAT': doc['lat']}}})
#       5     i += 1
#       6     if i%10000 == 0:
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/collection.py in update_one(self, filter, update, upsert, bypass_document_validation, collation, array_filters, session)
#     974                 bypass_doc_val=bypass_document_validation,
#     975                 collation=collation, array_filters=array_filters,
# --> 976                 session=session),
#     977             self.write_concern.acknowledged)
#     978
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/collection.py in _update_retryable(self, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session)
#     834         return self.__database.client._retryable_write(
#     835             (write_concern or self.write_concern).acknowledged and not multi,
# --> 836             _update, session)
#     837
#     838     def replace_one(self, filter, replacement, upsert=False,
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1100         """Internal retryable write helper."""
#    1101         with self._tmp_session(session) as s:
# -> 1102             return self._retry_with_session(retryable, func, s, None)
#    1103
#    1104     def __reset_server(self, address):
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1077                         # Reset the transaction id and retry the operation.
#    1078                         session._retry_transaction_id()
# -> 1079                     return func(session, sock_info, retryable)
#    1080             except ServerSelectionTimeoutError:
#    1081                 if is_retrying():
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/collection.py in _update(session, sock_info, retryable_write)
#     830                 bypass_doc_val=bypass_doc_val, collation=collation,
#     831                 array_filters=array_filters, session=session,
# --> 832                 retryable_write=retryable_write)
#     833
#     834         return self.__database.client._retryable_write(
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pymongo/collection.py in _update(self, sock_info, criteria, document, upsert, check_keys, multi, manipulate, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, session, retryable_write)
#     758                           ('u', document),
#     759                           ('multi', multi),
# --> 760                           ('upsert', upsert)])
#     761         if collation is not None:
#     762             if sock_info.max_wire_version < 5:
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/bson/son.py in __init__(self, data, **kwargs)
#      38     """
#      39
# ---> 40     def __init__(self, data=None, **kwargs):
#      41         self.__keys = []
#      42         dict.__init__(self)
#
# KeyboardInterrupt:
